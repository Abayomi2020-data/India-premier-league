# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_league = pd.read_csv("C:/Users/hp/Documents/data/deliveries.csv")
df_league.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df_league.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
filt = df_league["batsman"]=="DA Warner"

# %%
df_league_warner = df_league[filt]

# %%
df_league_warner.shape
# Out:
# (2902, 21)

# %%
df_league_warner["dismissal_kind"].value_counts()
# Out:
# caught               62
# bowled               21
# run out               8
# lbw                   4
# stumped               4
# caught and bowled     2
# hit wicket            1
# Name: dismissal_kind, dtype: int64

# %%
df_league_warner["dismissal_kind"].value_counts().plot.pie()
plt.show()

# %%
len(df_league_warner[df_league_warner["batsman_runs"]==4])
# Out:
# 401

# %%
len(df_league_warner[df_league_warner["batsman_runs"]==6])
# Out:
# 160

# %%
def count(df_league, runs):
    return len(df_league_warner[df_league_warner["batsman_runs"]==runs])*runs

# %%
count(df_league_warner, 1)
# Out:
# 997

# %%
count(df_league_warner, 2)
# Out:
# 414

# %%
count(df_league_warner, 3)
# Out:
# 39

# %%
count(df_league_warner, 4)
# Out:
# 1604

# %%
count(df_league_warner, 6)
# Out:
# 960

# %%
slices = [997, 414, 39, 1604, 960]
labels = [1,2,3,4,6]
explode = [0,0.2,0.1,0.1,0]
plt.pie(slices, labels=labels, autopct="% 1.1f%%",explode=explode)
plt.show()

# %%
df_league.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df_league["bowling_team"].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
Teams = {
    'Royal Challengers Bangalore':'RCB', 'Sunrisers Hyderabad':'SRH',
       'Rising Pune Supergiant':'RPS', 'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 'Gujarat Lions':'GL', 'Kings XI Punjab':'KXIP',
       'Delhi Daredevils':'DD', 'Chennai Super Kings':'CSK', 'Rajasthan Royals':'RR',
       'Deccan Chargers':'DC', 'Kochi Tuskers Kerala':'KTK', 'Pune Warriors':'PW',
       'Rising Pune Supergiants':'RPS'
}

# %%
df_league["batting_team"]= df_league["batting_team"].map(Teams)
df_league["bowling_team"] = df_league["bowling_team"].map(Teams)

# %%
df_league.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
df_league.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
runs = df_league.groupby(['match_id','inning','batting_team',])['total_runs'].sum().reset_index()
runs.head()
# Out:
#    match_id  inning batting_team  total_runs
# 0         1       1          SRH         207
# 1         1       2          RCB         172
# 2         2       1           MI         184
# 3         2       2          RPS         187
# 4         3       1           GL         183

# %%
runs.drop('match_id', axis=1, inplace=True)
runs.head()
# Out:
#    inning batting_team  total_runs
# 0       1          SRH         207
# 1       2          RCB         172
# 2       1           MI         184
# 3       2          RPS         187
# 4       1           GL         183

# %%
inning1=runs[runs['inning']==1]
inning2=runs[runs["inning"]==2]

# %%
sns.boxplot(x='batting_team', y='total_runs', data=inning1)
plt.show()

# %%
sns.boxplot(x='batting_team', y='total_runs', data=inning2)
plt.show()

# %%
high_scores = df_league.groupby(["match_id", "inning", "batting_team","bowling_team"])["total_runs"].sum().reset_index()

# %%
high_scores.head()
# Out:
#    match_id  inning batting_team bowling_team  total_runs
# 0         1       1          SRH          RCB         207
# 1         1       2          RCB          SRH         172
# 2         2       1           MI          RPS         184
# 3         2       2          RPS           MI         187
# 4         3       1           GL          KKR         183

# %%
score_200 = high_scores[high_scores["total_runs"]>=200]

# %%
score_200.head()
# Out:
#     match_id  inning batting_team bowling_team  total_runs
# 0          1       1          SRH          RCB         207
# 16         9       1           DD          RPS         205
# 38        20       1          RCB           GL         213
# 62        32       1          SRH         KXIP         207
# 72        36       1          SRH          KKR         209

# %%
sns.countplot(score_200["batting_team"])
plt.show()

# %%
sns.countplot(score_200["bowling_team"])
plt.show()

# %%
balls = df_league.groupby("batsman")["ball"].count().reset_index()

# %%
balls.head()
# Out:
#           batsman  ball
# 0  A Ashish Reddy   196
# 1      A Chandila     7
# 2        A Chopra    75
# 3     A Choudhary    20
# 4      A Flintoff    57

# %%
runs = df_league.groupby("batsman")["batsman_runs"].sum().reset_index()

# %%
runs.head()
# Out:
#           batsman  batsman_runs
# 0  A Ashish Reddy           280
# 1      A Chandila             4
# 2        A Chopra            53
# 3     A Choudhary            25
# 4      A Flintoff            62

# %%
four = df_league[df_league["batsman_runs"]==4]
four.head()
# Out:
#     match_id  inning batting_team bowling_team  over  ball       batsman  \
# 2          1       1          SRH          RCB     1     3     DA Warner
# 8          1       1          SRH          RCB     2     2     DA Warner
# 13         1       1          SRH          RCB     2     7  MC Henriques
# 30         1       1          SRH          RCB     5     5  MC Henriques
# 32         1       1          SRH          RCB     6     1      S Dhawan
#
#      non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 2       S Dhawan     TS Mills              0  ...         0            0
# 8       S Dhawan  A Choudhary              0  ...         0            0
# 13      S Dhawan  A Choudhary              0  ...         0            0
# 30      S Dhawan    S Aravind              0  ...         0            0
# 32  MC Henriques    SR Watson              0  ...         0            0
#
#     noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# ...

# %%
runs_4 = four.groupby("batsman")["batsman_runs"].count().reset_index()

# %%
runs_4.head()
# Out:
#           batsman  batsman_runs
# 0  A Ashish Reddy            16
# 1        A Chopra             7
# 2     A Choudhary             1
# 3      A Flintoff             5
# 4        A Kumble             3

# %%
runs_4.columns = ["batsman", "4s"]
runs_4.head()
# Out:
#           batsman  4s
# 0  A Ashish Reddy  16
# 1        A Chopra   7
# 2     A Choudhary   1
# 3      A Flintoff   5
# 4        A Kumble   3

# %%
six = df_league[df_league["batsman_runs"]==6]
six.head()
# Out:
#     match_id  inning batting_team bowling_team  over  ball       batsman  \
# 10         1       1          SRH          RCB     2     4     DA Warner
# 47         1       1          SRH          RCB     8     4  MC Henriques
# 75         1       1          SRH          RCB    13     2  Yuvraj Singh
# 89         1       1          SRH          RCB    15     3  Yuvraj Singh
# 91         1       1          SRH          RCB    15     5  MC Henriques
#
#      non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 10      S Dhawan  A Choudhary              0  ...         0            0
# 47      S Dhawan      TM Head              0  ...         0            0
# 75  MC Henriques  A Choudhary              0  ...         0            0
# 89  MC Henriques    S Aravind              0  ...         0            0
# 91  Yuvraj Singh    S Aravind              0  ...         0            0
#
#     noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# ...

# %%
six = six.groupby("batsman")["batsman_runs"].count().reset_index()

# %%
six.columns = ["batsman", "6s"]
six.head()
# Out:
#           batsman  6s
# 0  A Ashish Reddy  15
# 1     A Choudhary   1
# 2      A Flintoff   2
# 3        A Mishra   5
# 4        A Mithun   1

# %%
player = pd.concat([runs, balls.iloc[:,1], runs_4.iloc[:,1],six.iloc[:,1]], axis=1)
player
# Out:
#             batsman  batsman_runs  ball    4s    6s
# 0    A Ashish Reddy           280   196  16.0  15.0
# 1        A Chandila             4     7   7.0   1.0
# 2          A Chopra            53    75   1.0   2.0
# 3       A Choudhary            25    20   5.0   5.0
# 4        A Flintoff            62    57   3.0   1.0
# ..              ...           ...   ...   ...   ...
# 456     YV Takawale           192   183   NaN   NaN
# 457   Yashpal Singh            47    67   NaN   NaN
# 458     Younis Khan             3     7   NaN   NaN
# 459    Yuvraj Singh          2591  2050   NaN   NaN
# 460          Z Khan           117   141   NaN   NaN
#
# [461 rows x 5 columns]

# %%
player.fillna(0, inplace=True)

# %%
player.head()
# Out:
#           batsman  batsman_runs  ball    4s    6s
# 0  A Ashish Reddy           280   196  16.0  15.0
# 1      A Chandila             4     7   7.0   1.0
# 2        A Chopra            53    75   1.0   2.0
# 3     A Choudhary            25    20   5.0   5.0
# 4      A Flintoff            62    57   3.0   1.0

# %%
player["strike_rate"] = (player["batsman_runs"]/player["ball"])*100

# %%
player.head()
# Out:
#           batsman  batsman_runs  ball    4s    6s  strike_rate
# 0  A Ashish Reddy           280   196  16.0  15.0   142.857143
# 1      A Chandila             4     7   7.0   1.0    57.142857
# 2        A Chopra            53    75   1.0   2.0    70.666667
# 3     A Choudhary            25    20   5.0   5.0   125.000000
# 4      A Flintoff            62    57   3.0   1.0   108.771930

# %%
grp = df_league.groupby(["match_id", "batsman", "batting_team"])["batsman_runs"].sum().reset_index()

# %%
grp.head()
# Out:
#    match_id      batsman batting_team  batsman_runs
# 0         1  A Choudhary          RCB             6
# 1         1  BCJ Cutting          SRH            16
# 2         1     CH Gayle          RCB            32
# 3         1    DA Warner          SRH            14
# 4         1     DJ Hooda          SRH            16

# %%
max = grp.groupby("batsman")["batsman_runs"].max().reset_index()
max.columns = ["batsman", "max_runs"]
max.head()
# Out:
#           batsman  max_runs
# 0  A Ashish Reddy        36
# 1      A Chandila         4
# 2        A Chopra        24
# 3     A Choudhary        15
# 4      A Flintoff        24

# %%
player2 = pd.concat([player, max.iloc[:,1]], axis=1)
player2.head()
# Out:
#           batsman  batsman_runs  ball    4s    6s  strike_rate  max_runs
# 0  A Ashish Reddy           280   196  16.0  15.0   142.857143        36
# 1      A Chandila             4     7   7.0   1.0    57.142857         4
# 2        A Chopra            53    75   1.0   2.0    70.666667        24
# 3     A Choudhary            25    20   5.0   5.0   125.000000        15
# 4      A Flintoff            62    57   3.0   1.0   108.771930        24

# %%
max_runs = df_league.groupby("batsman")["batsman_runs"].sum()

# %%
max_runs.sort_values(ascending=False)[:10].plot(kind="bar")
plt.show()

# %% [markdown]
# ## SK Raina has  the highest run among the top ten batsman runner

# %%
df_league.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df_league.groupby(['match_id','batsman', 'batting_team'])['batsman_runs'].sum().reset_index().sort_values(by='batsman_runs', ascending=False).head(10)
# Out:
#       match_id         batsman batting_team  batsman_runs
# 6200       411        CH Gayle          RCB           175
# 900         60     BB McCullum          KKR           158
# 8426       562  AB de Villiers          RCB           133
# 9257       620  AB de Villiers          RCB           129
# 5585       372        CH Gayle          RCB           128
# 3135       206         M Vijay          CSK           127
# 529         36       DA Warner          SRH           126
# 7752       516        V Sehwag         KXIP           122
# 3686       243     PC Valthaty         KXIP           120
# 4223       279        V Sehwag           DD           119

# %% [markdown]
# ### Top 10 individual scores batsman

# %%
df_league["dismissal_kind"].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dismissal_kinds = ['caught', 'bowled', 'lbw', 'caught and bowled',
       'stumped', 'hit wicket']

# %%
hwt = df_league[df_league["dismissal_kind"].isin(dismissal_kinds)]

# %%
hwt.head()
# Out:
#      match_id  inning batting_team bowling_team  over  ball        batsman  \
# 11          1       1          SRH          RCB     2     5      DA Warner
# 64          1       1          SRH          RCB    11     3       S Dhawan
# 94          1       1          SRH          RCB    16     2   MC Henriques
# 116         1       1          SRH          RCB    19     4   Yuvraj Singh
# 160         1       2          RCB          SRH     6     4  Mandeep Singh
#
#       non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 11       S Dhawan  A Choudhary              0  ...         0            0
# 64   MC Henriques    STR Binny              0  ...         0            0
# 94   Yuvraj Singh    YS Chahal              0  ...         0            0
# 116      DJ Hooda     TS Mills              0  ...         0            0
# 160      CH Gayle  Rashid Khan              0  ...         0            0
#
# ...

# %%
hwt["bowler"].value_counts()[:10]
# Out:
# SL Malinga         154
# A Mishra           134
# Harbhajan Singh    127
# PP Chawla          126
# DJ Bravo           122
# B Kumar            111
# A Nehra            106
# R Vinay Kumar      103
# Z Khan             102
# R Ashwin           100
# Name: bowler, dtype: int64

# %%
hwt["bowler"].value_counts()[:10].plot()
plt.show()

# %%
hwt["bowler"].value_counts()[:10].plot(kind="bar")
plt.show()

# %% [markdown]
# ### SL Malinga has the highest wicket taker
